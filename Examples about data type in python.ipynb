# %% [markdown]
# # PYTHON DATA TYPES
# 1. Numbers
# 2. Booleans
# 3. Strings
# 4. Bytes
# 5. Lists
# 6. Arrays
# 7. Tuples
# 8. Sets
# 9. Dictionaries

# %% [markdown]
# # PYTHON DATA TYPES: NUMBERS
# 1. can be real number
# 2. can be complex number

# %% [markdown]
# 1. can be real number

# %%
print(120) # integar number
# Out:
# 120

# %% [markdown]
# 2. can be complex number

# %%
print(complex( 15.4, -8.5 ))
# Out:
# (15.4-8.5j)

# %% [markdown]
# # PYTHON DATA TYPES: Booleans
# 1. Ture = 1
# 2. False = 0

# %%
print( int(True) ,"   ", int(False) )
# Out:
# 1     0

# %% [markdown]
# # PYTHON DATA TYPES: BYTES
# ### Differences between strings and bytes:
# ###### 1. Byte object contains sequence of bytes while String contains sequence of characters.
# ###### 2. Bytes can be read by machines while strings can be read by humans.
# ###### 3. Bytes is stored directly on machines while strings needs to be encoded first.
# #

# %% [markdown]
# # PYTHON DATA TYPES: Strings

# %% [markdown]
# ![123.JPG](attachment:123.JPG)

# %%
string = "my name is Yahia"
print(string[0:16:1])
# Out:
# my name is Yahia

# %% [markdown]
# # Quiz
# ### ➔ What is the output of the followingcode?
# ##### my_string = "0123456789"
# ##### print(my_string[-2: -6: -2])
# ### Solution is: 86

# %% [markdown]
# # Variables
# 1. Variables can change type, simply by assigning them a new value ofa
# different type

# %%
x = 1
x = "String value"
type(x)
# Out:
# str

# %% [markdown]
# 2. Python allows you to assign a single value to severalvariables
# simultaneously

# %%
a = b = c = 1
print(a,b,c)
# Out:
# 1 1 1

# %% [markdown]
# 3. You can also assign multiple objects to multiplevariables

# %%
a , b , c = 4 , 3.2 , "hello"
print(a,b,c)
# Out:
# 4 3.2 hello
